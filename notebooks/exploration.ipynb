# %% [markdown]
# # EDA — Diabetes Prediction
# Basic exploratory data analysis. Replace this notebook with richer content if needed.

# %%
import pandas as pd
df = pd.read_csv('data/raw/pima_diabetes.csv')
df.head()
